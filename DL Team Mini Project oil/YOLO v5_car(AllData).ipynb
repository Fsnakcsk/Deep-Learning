# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="s7YmJeUA9IgceS1oxPfd")
# project = rf.workspace("project-ij6y9").project("moving-detection")
# dataset = project.version(1).download("yolov5")

# %%
# All Data
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="s7YmJeUA9IgceS1oxPfd")
project = rf.workspace("project-ij6y9").project("moving-detection")
dataset = project.version(2).download("yolov5")

# %%
from IPython.display import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks

# %%
#훈련
# !python train.py --img 640 --batch 20 --epochs 60 --data /content/Moving-detection-2/data.yaml --weights yolov5m.pt --cache
# Out:
# train: weights=yolov5m.pt, cfg=, data=/content/Moving-detection-2/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=20, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-47-g2370a55 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp4/weights/best.pt --img 640 --conf 0.35 --source /content/Moving-detection-2/test/images/frame120_png.rf.f25cbc69703a7ff7835e192d68d1b934.jpg

# %%
Image('/content/yolov5/runs/detect/exp2/frame120_png.rf.f25cbc69703a7ff7835e192d68d1b934.jpg')

# %%
# test
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.55 --source /content/Moving-detection-2/test/images/capture-112-_png.rf.6c73efcdab51625898f85bf1d1ab7ed0.jpg

# %%
Image('/content/yolov5/runs/detect/exp4/capture-112-_png.rf.6c73efcdab51625898f85bf1d1ab7ed0.jpg')

# %%
# test
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.55 --source /content/1150387_577246_3022.jpg

# %%
Image('/content/yolov5/runs/detect/exp7/1150387_577246_3022.jpg')

# %%
# test
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.65 --source /content/test_car_vdio.mp4

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp4/weights/best.pt --img 640 --conf 0.56 --source /content/Team_Mini_Project.mp4

# %%
# test
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.65 --source /content/캡처3.PNG

# %%
Image('/content/yolov5/runs/detect/exp14/캡처3.PNG')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !pip install youtube-dl
# !youtube-dl https://www.youtube.com/watch?v=If-A-Tz6e8M&ab_channel=YTN -f 22 -o video.mp4
# !ffmpeg -i video.mp4 -t 00:00:49 -c:v copy video-clip.mp4

# %%
import torch
from models.experimental import attempt_load

weights = 'runs/train/exp/weights/best.pt'
model = attempt_load(weights)
torch.save(model, 'model_with_shape.pt')
print("load and save model successfully!")
# Out:
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# load and save model successfully!
